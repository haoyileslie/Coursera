# %% [markdown]
# Create charts for GTI application

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the Excel file
file_path = r"C:\Users\lluo\OneDrive - cooperinvestors.com\My Documents\other docs\GTI\FinancialServiceFintech\5206037_Industry_Gross_Value_Added_Annual.xlsx"
df_VGA = pd.read_excel(file_path, sheet_name='Data1')

# Set the index of df to the first column
df_VGA.set_index(df_VGA.columns[0], inplace=True)
df_VGA.tail()
# Out:
#                     Agriculture, forestry and fishing (A) ;  Agriculture ;  \
# Unnamed: 0
# 2019-06-01 00:00:00                                              40550
# 2020-06-01 00:00:00                                              35903
# 2021-06-01 00:00:00                                              46182
# 2022-06-01 00:00:00                                              53783
# 2023-06-01 00:00:00                                              55679
#
#                     Agriculture, forestry and fishing (A) ;  Forestry and fishing ;  \
# Unnamed: 0
# 2019-06-01 00:00:00                                               8105
# 2020-06-01 00:00:00                                               8014
# 2021-06-01 00:00:00                                               7763
# 2022-06-01 00:00:00                                               8643
# 2023-06-01 00:00:00                                               8293
#
#                     Agriculture, forestry and fishing (A) ;  \
# ...

# %%
# Parse '2023-06-01' into a datetime object
date = pd.to_datetime('2023-06-01')
# Keep only the rows where the index is '2023-06-01'
df_VGA_2023 = df_VGA.loc[df_VGA.index == date]
df_VGA_2023
# Out:
#                     Agriculture, forestry and fishing (A) ;  Agriculture ;  \
# Unnamed: 0
# 2023-06-01 00:00:00                                              55679
#
#                     Agriculture, forestry and fishing (A) ;  Forestry and fishing ;  \
# Unnamed: 0
# 2023-06-01 00:00:00                                               8293
#
#                     Agriculture, forestry and fishing (A) ;  \
# Unnamed: 0
# 2023-06-01 00:00:00                                   63971
#
#                     Mining (B) ;  Coal Mining ;  \
# Unnamed: 0
# 2023-06-01 00:00:00                       87165
#
#                     Mining (B) ;  Oil and gas extraction ;  \
# Unnamed: 0
# 2023-06-01 00:00:00                                  79695
#
#                     Mining (B) ;  Iron ore mining ;  \
# Unnamed: 0
# 2023-06-01 00:00:00                          116484
#
#                     Mining (B) ;  Other mining ;  \
# Unnamed: 0
# 2023-06-01 00:00:00                        25495
#
# ...

# %%
# Split the column names on ';' and keep the first part
df_VGA_2023.columns = df_VGA_2023.columns.str.split(';').str[0]
df_VGA_2023
# Out:
#                     Agriculture, forestry and fishing (A)   \
# Unnamed: 0
# 2023-06-01 00:00:00                                  55679
#
#                     Agriculture, forestry and fishing (A)   \
# Unnamed: 0
# 2023-06-01 00:00:00                                   8293
#
#                     Agriculture, forestry and fishing (A)  Mining (B)   \
# Unnamed: 0
# 2023-06-01 00:00:00                                  63971       87165
#
#                     Mining (B)  Mining (B)  Mining (B)  Mining (B)   \
# Unnamed: 0
# 2023-06-01 00:00:00       79695      116484       25495      308840
#
#                     Mining (B)  Mining (B)   ...  \
# Unnamed: 0                                   ...
# 2023-06-01 00:00:00       12214      321053  ...
#
#                     Public administration and safety (O)   \
# Unnamed: 0
# 2023-06-01 00:00:00                                120238
#
#                     Education and training (P)   \
# Unnamed: 0
# ...

# %%
# Remove the last four columns from df
df_VGA_2023 = df_VGA_2023.iloc[:, :-4]
df_VGA_2023
# Out:
#                     Agriculture, forestry and fishing (A)   \
# Unnamed: 0
# 2023-06-01 00:00:00                                  55679
#
#                     Agriculture, forestry and fishing (A)   \
# Unnamed: 0
# 2023-06-01 00:00:00                                   8293
#
#                     Agriculture, forestry and fishing (A)  Mining (B)   \
# Unnamed: 0
# 2023-06-01 00:00:00                                  63971       87165
#
#                     Mining (B)  Mining (B)  Mining (B)  Mining (B)   \
# Unnamed: 0
# 2023-06-01 00:00:00       79695      116484       25495      308840
#
#                     Mining (B)  Mining (B)   ...  \
# Unnamed: 0                                   ...
# 2023-06-01 00:00:00       12214      321053  ...
#
#                     Professional, scientific and technical services (M)   \
# Unnamed: 0
# 2023-06-01 00:00:00                                              42056
#
# ...

# %%
# Sum the columns if their names are identical
df_VGA_2023_industry = df_VGA_2023.T.groupby(level=0).sum().T
df_VGA_2023_industry
# Out:
#                     Accommodation and food services (H)   \
# Unnamed: 0
# 2023-06-01 00:00:00                                52876
#
#                     Administrative and support services (N)   \
# Unnamed: 0
# 2023-06-01 00:00:00                                    80803
#
#                     Agriculture, forestry and fishing (A)   \
# Unnamed: 0
# 2023-06-01 00:00:00                                 127943
#
#                     Arts and recreation services (R)  Construction (E)   \
# Unnamed: 0
# 2023-06-01 00:00:00                             17151            317058
#
#                     Education and training (P)   \
# Unnamed: 0
# 2023-06-01 00:00:00                      106614
#
#                     Electricity, gas, water and waste services (D)   \
# Unnamed: 0
# 2023-06-01 00:00:00                                           90486
#
#                     Financial and insurance services (K)   \
# Unnamed: 0
# 2023-06-01 00:00:00                                326416
#
# ...

# %%
# Sum up all the rows to get a total for each column
totals = df_VGA_2023_industry.sum()

# Sort the totals from high to low
totals_sorted = totals.sort_values(ascending=False)

totals_sorted
# Out:
# Mining (B)                                              950946
# Professional, scientific and technical services (M)     340590
# Financial and insurance services (K)                    326416
# Construction (E)                                        317058
# Manufacturing (C)                                       247952
# Transport, postal and warehousing (I)                   218134
# Ownership of dwellings                                  196621
# Health care and social assistance (Q)                   183192
# Rental, hiring and real estate services (L)             128288
# Agriculture, forestry and fishing (A)                   127943
# Public administration and safety (O)                    120238
# Information media and telecommunications (J)            113761
# Education and training (P)                              106614
# Retail trade (G)                                         95695
# Electricity, gas, water and waste services (D)           90486
# ...

# %%
# Sum up all the rows to get a total for each column
totals = df_VGA_2023_industry.sum()

# Create a pie chart
patches, texts, autotexts = plt.pie(totals, labels=totals.index, autopct='%1.1f%%', pctdistance=1.1, labeldistance=1.2)

# Highlight the specific label and percentage
highlight = 'Financial and insurance services (K)'
for i in range(len(texts)):
    if texts[i].get_text() == highlight:
        texts[i].set_fontsize(14)
        texts[i].set_color('red')
        autotexts[i].set_fontsize(14)
        autotexts[i].set_color('red')
        texts[i].set_bbox(dict(facecolor='yellow', alpha=0.5, edgecolor='black'))
    else:
        texts[i].set_fontsize(8)  # Reduce the font size to 10
        autotexts[i].set_fontsize(8)  # Reduce the font size to 10

# Draw white circles at the center
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

# Equal aspect ratio ensures that pie is drawn as a circle.
plt.axis('equal')  

plt.show()

# %%
# Load the Excel file
file_path = r"C:\Users\lluo\OneDrive - cooperinvestors.com\My Documents\other docs\GTI\FinancialServiceFintech\5206037_Industry_Gross_Value_Added_Annual.xlsx"
df_VGA2 = pd.read_excel(file_path, sheet_name='Data1')

# Set the index of df to the first column
df_VGA2.set_index(df_VGA2.columns[0], inplace=True)
df_VGA2
# Out:
#                     Agriculture, forestry and fishing (A) ;  Agriculture ;  \
# Unnamed: 0
# Unit                                                        $ Millions
# Series Type                                                   Original
# Data Type                                                      DERIVED
# Frequency                                                       Annual
# Collection Month                                                     6
# ...                                                                ...
# 2019-06-01 00:00:00                                              40550
# 2020-06-01 00:00:00                                              35903
# 2021-06-01 00:00:00                                              46182
# 2022-06-01 00:00:00                                              53783
# 2023-06-01 00:00:00                                              55679
#
#                     Agriculture, forestry and fishing (A) ;  Forestry and fishing ;  \
# Unnamed: 0
# ...

# %%
# Ensure that the DataFrame's index only contains valid date strings
df_VGA2.index = pd.to_datetime(df_VGA2.index, errors='coerce')

# Drop any rows with invalid dates
df_VGA2 = df_VGA2.loc[df_VGA2.index.notnull()]

# Parse the dates into datetime objects
start_date = pd.to_datetime('1995-06-01')
end_date = pd.to_datetime('2023-06-01')

# Keep only the rows where the index is between '1995-06-01' and '2023-06-01'
df_VGA2_1995_2023 = df_VGA2.loc[(df_VGA2.index >= start_date) & (df_VGA2.index <= end_date)]
df_VGA2_1995_2023.head()
# Out:
# C:\Users\lluo\AppData\Local\Temp\ipykernel_12784\3765932441.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_VGA2.index = pd.to_datetime(df_VGA2.index, errors='coerce')
#            Agriculture, forestry and fishing (A) ;  Agriculture ;  \
# Unnamed: 0
# 1995-06-01                                              23624
# 1996-06-01                                              29684
# 1997-06-01                                              31843
# 1998-06-01                                              31804
# 1999-06-01                                              35489
#
#            Agriculture, forestry and fishing (A) ;  Forestry and fishing ;  \
# Unnamed: 0
# 1995-06-01                                               4173
# 1996-06-01                                               4306
# ...

# %%
# Split the column names on ';' and keep the first part
df_VGA2_1995_2023.columns = df_VGA2_1995_2023.columns.str.split(';').str[0]
df_VGA2_1995_2023.head()
# Out:
#            Agriculture, forestry and fishing (A)   \
# Unnamed: 0
# 1995-06-01                                  23624
# 1996-06-01                                  29684
# 1997-06-01                                  31843
# 1998-06-01                                  31804
# 1999-06-01                                  35489
#
#            Agriculture, forestry and fishing (A)   \
# Unnamed: 0
# 1995-06-01                                   4173
# 1996-06-01                                   4306
# 1997-06-01                                   4794
# 1998-06-01                                   4981
# 1999-06-01                                   5204
#
#            Agriculture, forestry and fishing (A)  Mining (B)  Mining (B)   \
# Unnamed: 0
# 1995-06-01                                  27555       32564       28138
# 1996-06-01                                  33361       32106       29013
# 1997-06-01                                  36041       36249       30551
# ...

# %%
# Sum the columns if their names are identical
df_VGA2_1995_2023_industry = df_VGA2_1995_2023.T.groupby(level=0).sum().T

# Remove the last four columns from df
df_VGA2_1995_2023_industry = df_VGA2_1995_2023_industry.iloc[:, :-4]
df_VGA2_1995_2023_industry.head()
# Out:
#            Accommodation and food services (H)   \
# Unnamed: 0
# 1995-06-01                                24763
# 1996-06-01                                24836
# 1997-06-01                                26332
# 1998-06-01                                27434
# 1999-06-01                                29766
#
#            Administrative and support services (N)   \
# Unnamed: 0
# 1995-06-01                                    30677
# 1996-06-01                                    30675
# 1997-06-01                                    31216
# 1998-06-01                                    34494
# 1999-06-01                                    37692
#
#            Agriculture, forestry and fishing (A)   \
# Unnamed: 0
# 1995-06-01                                  55352
# 1996-06-01                                  67351
# 1997-06-01                                  72678
# 1998-06-01                                  73086
# 1999-06-01                                  80644
#
# ...

# %%
# Calculate the number of years
num_years = df_VGA2_1995_2023_industry.index.max().year - df_VGA2_1995_2023_industry.index.min().year

# Calculate the CAGR for each column
cagr = (df_VGA2_1995_2023_industry.iloc[-1] / df_VGA2_1995_2023_industry.iloc[0]) ** (1 / num_years) - 1
cagr
# Out:
# Accommodation and food services (H)                     0.027463
# Administrative and support services (N)                 0.035194
# Agriculture, forestry and fishing (A)                   0.030376
# Arts and recreation services (R)                        0.031829
# Construction (E)                                        0.035479
# Education and training (P)                               0.02165
# Electricity, gas, water and waste services (D)          0.011665
# Financial and insurance services (K)                     0.03682
# GROSS DOMESTIC PRODUCT                                  0.030355
# Gross value added at basic prices                       0.031096
# Health care and social assistance (Q)                   0.046191
# Information media and telecommunications (J)            0.050028
# Manufacturing (C)                                       0.004632
# Mining (B)                                              0.039927
# ...

# %%
# Sort the CAGR values from high to low
cagr_sorted = cagr.sort_values(ascending=True)

# Create a list of colors, where 'red' corresponds to 'Financial and insurance services (K)' and 'blue' corresponds to all other columns
colors = ['red' if 'Financial and insurance services (K)' in index else 'blue' for index in cagr_sorted.index]

# Create a horizontal bar chart of the CAGR values
plt.figure(figsize=(10, 6))
bars = plt.barh(cagr_sorted.index, cagr_sorted.values, color=colors)
plt.xlabel('Compound annual growth rate (CAGR) ')

# # Add the value of each bar at the tip of the bar
# for bar in bars:
#     plt.text(bar.get_width(), bar.get_y() + bar.get_height() / 2, 
#              '{:.2f}'.format(bar.get_width()), 
#              va='center', ha='left')

plt.show()

# %%
from matplotlib.ticker import FuncFormatter

# Create a horizontal bar chart of the CAGR values
plt.figure(figsize=(10, 6))
bars = plt.barh(cagr_sorted.index, cagr_sorted.values, color=colors)

# Format the x-axis labels as percentages
formatter = FuncFormatter(lambda y, _: '{:.1%}'.format(y))
plt.gca().xaxis.set_major_formatter(formatter)

plt.xlabel('Compound annual growth rate (CAGR)')

# Add the value of each bar at the tip of the bar
for bar in bars:
    plt.text(bar.get_width(), bar.get_y() + bar.get_height() / 2, 
             '{:.1f}%'.format(bar.get_width() * 100), 
             va='center', ha='left')

plt.show()

# %%
import pandas as pd

# Specify the file path
file_path = r'C:\Users\lluo\OneDrive - cooperinvestors.com\My Documents\other docs\GTI\FinancialServiceFintech\5352015_2022.xlsx'

# Load the Excel file
df_FDI = pd.read_excel(file_path, sheet_name='15a')

df_FDI
# Out:
#                       Australian Bureau of Statistics Unnamed: 1 Unnamed: 2  \
# 0   5352.0 - International Investment Position, Au...        NaN        NaN
# 1      Released at 11.30am (Canberra time) 3 May 2023        NaN        NaN
# 2                                                 NaN        NaN        NaN
# 3   Table 15a. Foreign Investment in Australia(a):...        NaN        NaN
# 4           Direct Investment in Australia ($million)        NaN        NaN
# 5                                                 NaN        NaN        NaN
# 6                                            Industry       2018       2019
# 7                                                 NaN        NaN        NaN
# 8                   Agriculture, Forestry and Fishing       3163       3388
# 9                                Mining and Quarrying     374150     377292
# 10                                      Manufacturing     105549     126928
# ...

# %%
# Keep only rows 6 to 27
df_FDI_industry = df_FDI.iloc[6:27]

# Replace 'np' with 'NaN'
df_FDI_industry = df_FDI_industry.replace('np', float('NaN'))

df_FDI_industry
# Out:
#                       Australian Bureau of Statistics  Unnamed: 1  Unnamed: 2  \
# 6                                            Industry      2018.0      2019.0
# 7                                                 NaN         NaN         NaN
# 8                   Agriculture, Forestry and Fishing      3163.0      3388.0
# 9                                Mining and Quarrying    374150.0    377292.0
# 10                                      Manufacturing    105549.0    126928.0
# 11  Electricity, Gas, Steam and Air Conditioning S...     22216.0     22710.0
# 12                                       Construction     21231.0     21414.0
# 13  Wholesale and Retail Trade; Repair Of Motor Ve...     59676.0     59189.0
# 14          Accommodation and Food Service Activities      8866.0      9323.0
# 15                         Transportation and Storage     26093.0     26584.0
# 16                      Information and Communication     27720.0     31044.0
# ...

# %%
# Use the first row as column names
df_FDI_industry.columns = df_FDI_industry.iloc[0]
# Drop the first two rows
df_FDI_industry = df_FDI_industry.drop(df_FDI_industry.index[:2])
# Set the index to the first column
df_FDI_industry = df_FDI_industry.set_index(df_FDI_industry.columns[0])

# Convert the column names to integers
df_FDI_industry.columns = df_FDI_industry.columns.astype(int)

df_FDI_industry
# Out:
# 6                                                       2018      2019  \
# Industry
# Agriculture, Forestry and Fishing                     3163.0    3388.0
# Mining and Quarrying                                374150.0  377292.0
# Manufacturing                                       105549.0  126928.0
# Electricity, Gas, Steam and Air Conditioning Su...   22216.0   22710.0
# Construction                                         21231.0   21414.0
# Wholesale and Retail Trade; Repair Of Motor Veh...   59676.0   59189.0
# Accommodation and Food Service Activities             8866.0    9323.0
# Transportation and Storage                           26093.0   26584.0
# Information and Communication                        27720.0   31044.0
# Financial and Insurance Activities                  111488.0  108827.0
# Real Estate Activities                              107358.0  115600.0
# Professional, Scientific and Technical Activities     7114.0   10250.0
# ...

# %%
df_FDI_industry_2022 = df_FDI_industry[2022]

df_FDI_industry_2022
# Out:
# Industry
# Agriculture, Forestry and Fishing                                                                                             4050.0
# Mining and Quarrying                                                                                                        359256.0
# Manufacturing                                                                                                               118424.0
# Electricity, Gas, Steam and Air Conditioning Supply; Water Supply, Sewerage, Waste Management and Remediation Activities     26609.0
# Construction                                                                                                                 19006.0
# Wholesale and Retail Trade; Repair Of Motor Vehicles and Motor Cycles                                                        67069.0
# Accommodation and Food Service Activities                                                                                     9662.0
# ...

# %%
# Sort the DataFrame in descending order
df_FDI_industry_2022_sorted = df_FDI_industry_2022.sort_values(ascending=False)

df_FDI_industry_2022_sorted
# Out:
# Industry
# Mining and Quarrying                                                                                                        359256.0
# Real Estate Activities                                                                                                      144922.0
# Financial and Insurance Activities                                                                                          141164.0
# Unallocated                                                                                                                 127666.0
# Manufacturing                                                                                                               118424.0
# Wholesale and Retail Trade; Repair Of Motor Vehicles and Motor Cycles                                                        67069.0
# Information and Communication                                                                                                34342.0
# ...

# %%
import pandas as pd

# Sort the DataFrame in descending order
df_FDI_industry_2022_sorted = df_FDI_industry_2022.sort_values(ascending=False)

# Create two separate lists: one for the first half of the sorted series and one for the second half
first_half = df_FDI_industry_2022_sorted.index[:len(df_FDI_industry_2022_sorted)//2]
second_half = df_FDI_industry_2022_sorted.index[-(len(df_FDI_industry_2022_sorted)//2):][::-1]

# Interleave the two lists
zigzag_indices = [index for pair in zip(first_half, second_half) for index in pair]
if len(df_FDI_industry_2022_sorted) % 2:
    zigzag_indices.append(df_FDI_industry_2022_sorted.index[len(df_FDI_industry_2022_sorted)//2])
df_FDI_industry_2022_zigzag = df_FDI_industry_2022_sorted.loc[zigzag_indices]

# Create a pie chart
fig, ax = plt.subplots(figsize=(10, 6))
ax.pie(df_FDI_industry_2022_zigzag, labels = 
       [f'{index.split(";")[0]}: ${value/1000:.1f}bn, {value/df_FDI_industry_2022_zigzag.sum()*100:.1f}%' for index, value in df_FDI_industry_2022_zigzag.items()], 
       textprops={'fontsize': 8})

# Display the plot
plt.show()

# %%
import pandas as pd

# Load the file
df_gdp = pd.read_excel(r'C:\Users\lluo\OneDrive - cooperinvestors.com\My Documents\other docs\GTI\FinancialServiceFintech\OECDoutlookAU.xls', engine='xlrd')

# Keep only the rows 'Time' and 'Gross domestic product, nominal value, market prices'
df_gdp_clean = df_gdp.loc[df_gdp['Variable'].isin(['Time', 'Gross domestic product, nominal value, market prices'])]

df_gdp_clean
# Out:
# ---------------------------------------------------------------------------
# XLRDError                                 Traceback (most recent call last)
# Cell In[189], line 4
#       1 import pandas as pd
#       3 # Load the file
# ----> 4 df_gdp = pd.read_excel(r'C:\Users\lluo\OneDrive - cooperinvestors.com\My Documents\other docs\GTI\FinancialServiceFintech\OECDoutlookAU.xls', engine='xlrd')
#       6 # Keep only the rows 'Time' and 'Gross domestic product, nominal value, market prices'
#       7 df_gdp_clean = df_gdp.loc[df_gdp['Variable'].isin(['Time', 'Gross domestic product, nominal value, market prices'])]
#
# ...

# %%
import pandas as pd

# Load the file
df_gdp = pd.read_csv(r'C:\Users\lluo\OneDrive - cooperinvestors.com\My Documents\other docs\GTI\FinancialServiceFintech\OECDoutlookAU.csv')

# Keep only the rows where 'Country' is 'Australia' and 'Variable' is 'Gross domestic product, volume, market prices'
df_gdp_au = df_gdp.loc[(df_gdp['Country'] == 'Australia') & (df_gdp['Variable'] == 'Gross domestic product, volume, market prices')]

df_gdp_au.head()
# Out:
#     LOCATION    Country VARIABLE  \
# 112      AUS  Australia     GDPV
# 113      AUS  Australia     GDPV
# 114      AUS  Australia     GDPV
# 115      AUS  Australia     GDPV
# 116      AUS  Australia     GDPV
#
#                                           Variable FREQUENCY Frequency  TIME  \
# 112  Gross domestic product, volume, market prices         A    Annual  2012
# 113  Gross domestic product, volume, market prices         A    Annual  2013
# 114  Gross domestic product, volume, market prices         A    Annual  2014
# 115  Gross domestic product, volume, market prices         A    Annual  2015
# 116  Gross domestic product, volume, market prices         A    Annual  2016
#
#      Time Unit Code               Unit  PowerCode Code PowerCode  \
# 112  2012       AUD  Australian Dollar               0     Units
# 113  2013       AUD  Australian Dollar               0     Units
# 114  2014       AUD  Australian Dollar               0     Units
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

# Filter the DataFrame to include only the years from 2014 onwards
df_gdp_au = df_gdp_au[df_gdp_au['Time'] >= 2013]

# Convert the values into trillion
df_gdp_au['Value'] = df_gdp_au['Value'] / 1e12

# Create a list of colors
colors = ['red' if year in [2024, 2025] else 'blue' for year in df_gdp_au['Time']]

# Plot a bar chart
plt.figure(figsize=(15, 8))
bars = plt.bar(df_gdp_au['Time'], df_gdp_au['Value'], color=colors)
plt.xlabel('Year')
plt.ylabel('Gross domestic product, volume, market prices in AU$ (trillion)')

# Set the start and end year on the x-axis
plt.xlim(2012, 2026)

# Set the y-axis to fit the largest value of the bars
plt.ylim(0, df_gdp_au['Value'].max() * 1.1)  # Add a 10% margin

# Label each year on the x-axis
plt.xticks(df_gdp_au['Time'])

# Format the y-axis labels to hide the scientific notation
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, pos: f'{x:.2f}T'))

# Add the values on top of each bar
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom')

plt.show()

# %%
import pandas as pd

# Define the file path
file_path = r"C:\Users\lluo\OneDrive - cooperinvestors.com\My Documents\other docs\GTI\FinancialServiceFintech\6291004.xlsx"

# Read the data from the 'Data1' worksheet of the Excel file
df_emp = pd.read_excel(file_path, sheet_name='Data1')

# Set the index of df to the first column
df_emp.set_index(df_emp.columns[0], inplace=True)

# Display the first few rows of the DataFrame
df_emp.head()
# Out:
#                  Agriculture, Forestry and Fishing ;  Employed total ;  \
# Unnamed: 0
# Unit                                                            000
# Series Type                                                   Trend
# Data Type                                                     STOCK
# Frequency                                                   Quarter
# Collection Month                                                  2
#
#                  Agriculture, Forestry and Fishing ;  Employed total ;.1  \
# Unnamed: 0
# Unit                                                            000
# Series Type                                     Seasonally Adjusted
# Data Type                                                     STOCK
# Frequency                                                   Quarter
# Collection Month                                                  2
#
#                  Agriculture, Forestry and Fishing ;  Employed total ;.2  \
# Unnamed: 0
# ...

# %%
# Parse '2023-11-01' into a datetime object
date = pd.to_datetime('2023-11-01')
series_type = 'Series Type'  # The index name

# Keep only the rows where the index is '2023-11-01'
df_emp_2023 = df_emp.loc[(df_emp.index == date) | (df_emp.index == 'Series Type')]
df_emp_2023
# Out:
#                     Agriculture, Forestry and Fishing ;  Employed total ;  \
# Unnamed: 0
# Series Type                                                      Trend
# 2023-11-01 00:00:00                                          302.57185
#
#                     Agriculture, Forestry and Fishing ;  Employed total ;.1  \
# Unnamed: 0
# Series Type                                        Seasonally Adjusted
# 2023-11-01 00:00:00                                         304.779175
#
#                     Agriculture, Forestry and Fishing ;  Employed total ;.2  \
# Unnamed: 0
# Series Type                                                   Original
# 2023-11-01 00:00:00                                         308.982027
#
#                     Mining ;  Employed total ; Mining ;  Employed total ;.1  \
# Unnamed: 0
# Series Type                              Trend          Seasonally Adjusted
# 2023-11-01 00:00:00                  309.40956                   308.965681
#
# ...

# %% [markdown]
# the data frame has two index, one is 'Series Type', the other is 2023-11-01, I want to keep the columns based on 'Series Type' value, which is Original

# %%
df_emp_2023_original = df_emp_2023.iloc[:, 2::3]
df_emp_2023_original
# Out:
#                     Agriculture, Forestry and Fishing ;  Employed total ;.2  \
# Unnamed: 0
# Series Type                                                   Original
# 2023-11-01 00:00:00                                         308.982027
#
#                     Mining ;  Employed total ;.2  \
# Unnamed: 0
# Series Type                             Original
# 2023-11-01 00:00:00                   299.440895
#
#                     Manufacturing ;  Employed total ;.2  \
# Unnamed: 0
# Series Type                                    Original
# 2023-11-01 00:00:00                          933.503755
#
#                     Electricity, Gas, Water and Waste Services ;  Employed total ;.2  \
# Unnamed: 0
# Series Type                                                   Original
# 2023-11-01 00:00:00                                           162.5403
#
#                     Construction ;  Employed total ;.2  \
# Unnamed: 0
# Series Type                                   Original
# ...

# %%
# Split the column names on ';' and keep the first part
df_emp_2023_original.columns = df_emp_2023_original.columns.str.split(';').str[0]
df_emp_2023_original
# Out:
#                     Agriculture, Forestry and Fishing      Mining   \
# Unnamed: 0
# Series Type                                   Original    Original
# 2023-11-01 00:00:00                         308.982027  299.440895
#
#                     Manufacturing   \
# Unnamed: 0
# Series Type               Original
# 2023-11-01 00:00:00     933.503755
#
#                     Electricity, Gas, Water and Waste Services  Construction   \
# Unnamed: 0
# Series Type                                            Original      Original
# 2023-11-01 00:00:00                                    162.5403   1350.537335
#
#                     Wholesale Trade  Retail Trade   \
# Unnamed: 0
# Series Type                 Original      Original
# 2023-11-01 00:00:00       377.837471   1321.513089
#
#                     Accommodation and Food Services   \
# Unnamed: 0
# Series Type                                 Original
# 2023-11-01 00:00:00                       894.384566
#
# ...

# %%
# Remove the last 1 columns from df
df_emp_2023_original = df_emp_2023_original.iloc[:, :-1]
df_emp_2023_original
# Out:
#                     Agriculture, Forestry and Fishing      Mining   \
# Unnamed: 0
# Series Type                                   Original    Original
# 2023-11-01 00:00:00                         308.982027  299.440895
#
#                     Manufacturing   \
# Unnamed: 0
# Series Type               Original
# 2023-11-01 00:00:00     933.503755
#
#                     Electricity, Gas, Water and Waste Services  Construction   \
# Unnamed: 0
# Series Type                                            Original      Original
# 2023-11-01 00:00:00                                    162.5403   1350.537335
#
#                     Wholesale Trade  Retail Trade   \
# Unnamed: 0
# Series Type                 Original      Original
# 2023-11-01 00:00:00       377.837471   1321.513089
#
#                     Accommodation and Food Services   \
# Unnamed: 0
# Series Type                                 Original
# 2023-11-01 00:00:00                       894.384566
#
# ...

# %%
import matplotlib.pyplot as plt

# Remove the first row
df_emp_2023_original_chart = df_emp_2023_original.iloc[1:]

# Use the second row to create a horizontal bar chart
second_row = df_emp_2023_original_chart.iloc[0]

# Calculate the percentage of each column against the total across all the columns
percentages = second_row / second_row.sum() * 100

# Sort the percentages in descending order
percentages = percentages.sort_values(ascending=True)

percentages
# Out:
# Electricity, Gas, Water and Waste Services           1.134638
# Information Media and Telecommunications             1.315755
# Rental, Hiring and Real Estate Services              1.400014
# Arts and Recreation Services                         1.982568
# Mining                                               2.090294
# Agriculture, Forestry and Fishing                    2.156897
# Wholesale Trade                                      2.637553
# Administrative and Support Services                  2.990785
# Other Services                                       3.715952
# Financial and Insurance Services                     3.955575
# Transport, Postal and Warehousing                    5.268785
# Accommodation and Food Services                       6.24339
# Public Administration and Safety                     6.499318
# Manufacturing                                        6.516467
# Education and Training                                8.60983
# ...

# %%
# Create a list of colors, where 'red' corresponds to 'Financial and insurance services' and 'blue' corresponds to all other columns
colors = ['red' if 'Financial and Insurance Services' in index else 'blue' for index in percentages.index]

# Create a horizontal bar chart 
plt.figure(figsize=(10, 6))
bars = plt.barh(percentages.index, percentages.values, color=colors)
plt.xlabel('Percentage of total employed persons in November 2023')

# Add the value of each column at the tip of the bar
for bar in bars:
    plt.text(bar.get_width(), bar.get_y() + bar.get_height() / 2, f'{bar.get_width():.2f}', va='center')

plt.show()

# %%
import pandas as pd

# Define the file path
file_path = r"C:\Users\lluo\OneDrive - cooperinvestors.com\My Documents\other docs\GTI\FinancialServiceFintech\6291004.xlsx"

# Read the data from the 'Data1' worksheet of the Excel file
df_emp = pd.read_excel(file_path, sheet_name='Data1')

# Set the index of df to the first column
df_emp.set_index(df_emp.columns[0], inplace=True)

# Display the first few rows of the DataFrame
df_emp.head()
# Out:
#                  Agriculture, Forestry and Fishing ;  Employed total ;  \
# Unnamed: 0
# Unit                                                            000
# Series Type                                                   Trend
# Data Type                                                     STOCK
# Frequency                                                   Quarter
# Collection Month                                                  2
#
#                  Agriculture, Forestry and Fishing ;  Employed total ;.1  \
# Unnamed: 0
# Unit                                                            000
# Series Type                                     Seasonally Adjusted
# Data Type                                                     STOCK
# Frequency                                                   Quarter
# Collection Month                                                  2
#
#                  Agriculture, Forestry and Fishing ;  Employed total ;.2  \
# Unnamed: 0
# ...

# %%
df_emp_original = df_emp.iloc[:, 2::3]
df_emp_original
# Out:
#                     Agriculture, Forestry and Fishing ;  Employed total ;.2  \
# Unnamed: 0
# Unit                                                               000
# Series Type                                                   Original
# Data Type                                                        STOCK
# Frequency                                                      Quarter
# Collection Month                                                     2
# ...                                                                ...
# 2022-11-01 00:00:00                                         296.858289
# 2023-02-01 00:00:00                                         305.771209
# 2023-05-01 00:00:00                                         300.260151
# 2023-08-01 00:00:00                                         298.268689
# 2023-11-01 00:00:00                                         308.982027
#
#                     Mining ;  Employed total ;.2  \
# Unnamed: 0
# ...

# %%
# Split the column names on ';' and keep the first part
df_emp_original.columns = df_emp_original.columns.str.split(';').str[0]
df_emp_original
# Out:
#                     Agriculture, Forestry and Fishing      Mining   \
# Unnamed: 0
# Unit                                               000         000
# Series Type                                   Original    Original
# Data Type                                        STOCK       STOCK
# Frequency                                      Quarter     Quarter
# Collection Month                                     2           2
# ...                                                ...         ...
# 2022-11-01 00:00:00                         296.858289  277.932353
# 2023-02-01 00:00:00                         305.771209  285.258154
# 2023-05-01 00:00:00                         300.260151  311.303908
# 2023-08-01 00:00:00                         298.268689  300.335044
# 2023-11-01 00:00:00                         308.982027  299.440895
#
#                     Manufacturing   \
# Unnamed: 0
# Unit                           000
# Series Type               Original
# ...

# %%
print(df_emp_original.columns)
# Out:
# Index(['Agriculture, Forestry and Fishing ', 'Mining ', 'Manufacturing ',
#        'Electricity, Gas, Water and Waste Services ', 'Construction ',
#        'Wholesale Trade ', 'Retail Trade ', 'Accommodation and Food Services ',
#        'Transport, Postal and Warehousing ',
#        'Information Media and Telecommunications ',
#        'Financial and Insurance Services ',
#        'Rental, Hiring and Real Estate Services ',
#        'Professional, Scientific and Technical Services ',
#        'Administrative and Support Services ',
#        'Public Administration and Safety ', 'Education and Training ',
#        'Health Care and Social Assistance ', 'Arts and Recreation Services ',
#        'Other Services ', 'Employed total '],
#       dtype='object')

# %%
df_emp_original_finance = df_emp_original[['Financial and Insurance Services ','Employed total ']]
df_emp_original_finance
# Out:
#                     Financial and Insurance Services  Employed total
# Unnamed: 0
# Unit                                              000             000
# Series Type                                  Original        Original
# Data Type                                       STOCK           STOCK
# Frequency                                     Quarter         Quarter
# Collection Month                                    2               2
# ...                                               ...             ...
# 2022-11-01 00:00:00                        565.895714    13879.537489
# 2023-02-01 00:00:00                        537.360038    13968.302751
# 2023-05-01 00:00:00                        552.108252    14135.346403
# 2023-08-01 00:00:00                        546.105565    14066.871586
# 2023-11-01 00:00:00                         566.64812    14325.303712
#
# [166 rows x 2 columns]

# %%
# Ensure that the DataFrame's index only contains valid date strings
df_emp_original_finance.index = pd.to_datetime(df_emp_original_finance.index, errors='coerce')

# Drop any rows with invalid dates
df_emp_original_finance2 = df_emp_original_finance.loc[df_emp_original_finance.index.notnull()]

# Parse the dates into datetime objects
start_date = pd.to_datetime('2000-06-01')
end_date = pd.to_datetime('2023-11-01')

# Keep only the rows where the index is between '2000-06-01' and '2023-11-01'
df_emp_original_finance2_2000_2023 = df_emp_original_finance2.loc[(df_emp_original_finance2.index >= start_date) & (df_emp_original_finance2.index <= end_date)]
df_emp_original_finance2_2000_2023.head()
# Out:
# C:\Users\lluo\AppData\Local\Temp\ipykernel_12784\2033919795.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_emp_original_finance.index = pd.to_datetime(df_emp_original_finance.index, errors='coerce')
#            Financial and Insurance Services  Employed total
# Unnamed: 0
# 2000-08-01                        325.244305      8911.58789
# 2000-11-01                        326.551329     8912.719473
# 2001-02-01                        327.996245     8920.935432
# 2001-05-01                        347.094958     9004.629114
# 2001-08-01                        344.418873     8971.895396

# %%
# create a column to calculate the percentage of employed persons in finance industry
df_emp_original_finance2_2000_2023['percentage'] = 100 * df_emp_original_finance2_2000_2023['Financial and Insurance Services '] / df_emp_original_finance2_2000_2023['Employed total ']
df_emp_original_finance2_2000_2023
# Out:
# C:\Users\lluo\AppData\Local\Temp\ipykernel_12784\2106836384.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_emp_original_finance2_2000_2023['percentage'] = 100 * df_emp_original_finance2_2000_2023['Financial and Insurance Services '] / df_emp_original_finance2_2000_2023['Employed total ']
#            Financial and Insurance Services  Employed total  percentage  \
# Unnamed: 0
# 2000-08-01                        325.244305      8911.58789   3.649678
# 2000-11-01                        326.551329     8912.719473    3.66388
# 2001-02-01                        327.996245     8920.935432   3.676702
# 2001-05-01                        347.094958     9004.629114   3.854628
# ...

# %%
# draw a line chart to show the percentage of employed persons in finance industry
plt.figure(figsize=(18, 4))
plt.plot(df_emp_original_finance2_2000_2023['percentage'], marker='o')

# set the x axis to display the every 2 dates
plt.xticks(df_emp_original_finance2_2000_2023.index[::2], rotation=90)

plt.show()
